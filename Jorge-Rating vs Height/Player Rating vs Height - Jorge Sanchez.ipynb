# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "data.csv"

# %%
df = pd.read_csv(file)
pd.set_option('display.max_columns', None)
df
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
df.isnull().sum().head()
# Out:
# Unnamed: 0    0
# ID            0
# Name          0
# Age           0
# Photo         0
# dtype: int64

# %%
# DATA CLEANING

# Cleaning up numeric columns : wage, value, release clause 
df["Release Clause"]=df["Release Clause"].str.replace("M","000000")
df["Release Clause"]=df["Release Clause"].str.replace("K","000")
df["Release Clause"]=df["Release Clause"].str.replace("€","")
df["Release Clause"]=df["Release Clause"].str.replace(".","")
df["Release Clause"] = df["Release Clause"].astype(float)

# %%
df["Wage"]=df["Wage"].str.replace("M","000000")
df["Wage"]=df["Wage"].str.replace("K","000")
df["Wage"]=df["Wage"].str.replace("€","")
df["Wage"]=df["Wage"].str.replace(".","")
df["Wage"] = df["Wage"].astype(int)

# %%
df["Value"]=df["Value"].str.replace("M","000000")
df["Value"]=df["Value"].str.replace("K","000")
df["Value"]=df["Value"].str.replace("€","")
df["Value"]=df["Value"].str.replace(".","")
df["Value"] = df["Value"].astype(int)

# %%
df
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
# Combining the positions
def player_positions(x):
    a = ['GK']
    b = ['LWB','RWB','LB','LCB','CB','RCB','RB']
    c = ['LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LDM', 'CDM', 'RDM']
    d = ['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW']
    if x in a:
        return 'Goalkeeper'
    elif x in b:
        return 'Defenders'
    elif x in c:
        return 'Midfielder'
    elif x in d:
        return 'Attacker'
    else:
        return 'NaN'
df['Simplified Position'] = df['Position'].apply(player_positions)

# %%
df
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
#Look at the height of players in relation to their overall rating and heights in inches

height_df = pd.DataFrame(df,columns=["Name",'Height(Inches)', 'Overall'])
height_df.head()
# Out:
#                 Name Height(Inches)  Overall
# 0           L. Messi             67       94
# 1  Cristiano Ronaldo             74       94
# 2          Neymar Jr             69       92
# 3             De Gea             76       91
# 4       K. De Bruyne             61       91

# %%
top_ten_rated = height_df.head(10)
top_ten_rated
# Out:
#                 Name Height(Inches)  Overall
# 0           L. Messi             67       94
# 1  Cristiano Ronaldo             74       94
# 2          Neymar Jr             69       92
# 3             De Gea             76       91
# 4       K. De Bruyne             61       91
# 5          E. Hazard             68       91
# 6          L. Modrić             68       91
# 7          L. Suárez             72       91
# 8       Sergio Ramos             72       91
# 9           J. Oblak             74       90

# %%
#look at height and the relationship amongst the top 10 players in the world. 

x_axis_one = ["L. Messi",
"Cristiano Ronaldo",
"Neymar Jr",
"De Gea",
"K. De Bruyne",
"E. Hazard",
"L. Modrić",
"L. Suárez",
"Sergio Ramos",
"J. Oblak",
]

y_axis_one = [67,
74,
69,
76,
61,
68,
68,
72,
72,
74,
]

# %%
plt.scatter(x_axis_one, y_axis_one, marker="o", facecolors="red", edgecolors="black")
plt.xticks(x_axis_one, rotation='vertical')
plt.xlabel("Top 10 Players")
plt.ylabel("Height(Inches)")
plt.savefig("Top_10_players_and_height.png")

# %%
tick_locations = [value for value in x_axis_one]

plt.figure(figsize=(20,3))
plt.bar(x_axis_one, y_axis_one, color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, x_axis_one, rotation="vertical")
plt.xlabel("Top 10 Players")
plt.ylabel("Height(Inches)")
plt.savefig("Top_10_players_and_height_bar.png")

# %%
#We don't see a relationship of height amongst the top 10 rated players.
# players are listed by descending order of overall rating 
# the takklest player in the top is actually 4th in the

# %%
#We don't see a relationship of height amongst the top 10 rated players.
# players are listed by descending order of overall rating

# %%
height_df = pd.DataFrame(df,columns=["Name",'Height(Inches)', 'Overall'])
height_df.head()
# Out:
#                 Name Height(Inches)  Overall
# 0           L. Messi             67       94
# 1  Cristiano Ronaldo             74       94
# 2          Neymar Jr             69       92
# 3             De Gea             76       91
# 4       K. De Bruyne             61       91

# %%
height_df = height_df.truncate(before=0, after=1320)
height_df.head()
# Out:
#                 Name Height(Inches)  Overall
# 0           L. Messi             67       94
# 1  Cristiano Ronaldo             74       94
# 2          Neymar Jr             69       92
# 3             De Gea             76       91
# 4       K. De Bruyne             61       91

# %%
height_df["Height(Inches)"].max()
# Out:
# 79

# %%
height_df.max()
# Out:
# Name              Óliver Torres
# Height(Inches)               79
# Overall                      94
# dtype: object

# %%
height_df.min()
# Out:
# Name              A. Areola
# Height(Inches)           60
# Overall                  76
# dtype: object

# %%
height_df.median()
# Out:
# Overall    79.0
# dtype: float64

# %%
#convert the Height column into a float
height_df["Height(Inches)"] = height_df["Height(Inches)"].astype(float)

# %%
top_hundred_height = height_df.nlargest(100, ["Height(Inches)"])
top_hundred_height.head()
# Out:
#              Name  Height(Inches)  Overall
# 463       N. Pope            79.0       80
# 1204   L. Kalinić            79.0       76
# 19    T. Courtois            78.0       89
# 102         Naldo            78.0       85
# 210   R. Fährmann            78.0       83

# %%
plt.scatter(top_hundred_height["Overall"],top_hundred_height["Height(Inches)"],edgecolors="black",facecolors="green")
plt.title("Top 100 Tallest players vs overall rating ")
plt.xlabel("Overall Rating")
plt.ylabel("Height(Inches)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()
plt.savefig("Top_100_vs_overall_rating.png")
# %matplotlib inline

# %%
#You can see that the tallest player even has the lowest overall rating in the top 100. This is an interesting find
#however there are high ratings that can be seen in the data set.

# %%
#look at height in specific positions of a pleyer, isolate dataset
height_position_df = pd.DataFrame(df,columns=['Simplified Position','Overall','Height(Inches)'])
height_position_df.head()
# Out:
#   Simplified Position  Overall Height(Inches)
# 0            Attacker       94             67
# 1            Attacker       94             74
# 2            Attacker       92             69
# 3          Goalkeeper       91             76
# 4          Midfielder       91             61

# %%
height_position_df = height_position_df.truncate(before=0, after=1320)
height_position_df["Height(Inches)"] = height_position_df["Height(Inches)"].astype(float)
height_position_df["Overall"] = height_position_df["Overall"].astype(float)
height_position_df.head()
# Out:
#   Simplified Position  Overall  Height(Inches)
# 0            Attacker     94.0            67.0
# 1            Attacker     94.0            74.0
# 2            Attacker     92.0            69.0
# 3          Goalkeeper     91.0            76.0
# 4          Midfielder     91.0            61.0

# %%
height_position_df.sort_values(by=['Simplified Position']).head()
# Out:
#      Simplified Position  Overall  Height(Inches)
# 0               Attacker     94.0            67.0
# 659             Attacker     79.0            72.0
# 1054            Attacker     77.0            60.0
# 272             Attacker     82.0            67.0
# 271             Attacker     82.0            72.0

# %%
position_height_df = height_position_df.groupby('Simplified Position').groups.keys()
position_height_df
# Out:
# dict_keys(['Attacker', 'Defenders', 'Goalkeeper', 'Midfielder'])

# %%
gb_attacker = height_position_df.groupby("Simplified Position")
gb_attacker = gb_attacker.get_group("Attacker")
gb_attacker
# Out:
#      Simplified Position  Overall  Height(Inches)
# 0               Attacker     94.0            67.0
# 1               Attacker     94.0            74.0
# 2               Attacker     92.0            69.0
# 5               Attacker     91.0            68.0
# 7               Attacker     91.0            72.0
# 10              Attacker     90.0            72.0
# 15              Attacker     89.0            60.0
# 16              Attacker     89.0            74.0
# 21              Attacker     89.0            73.0
# 23              Attacker     89.0            68.0
# 29              Attacker     88.0            64.0
# 30              Attacker     88.0            69.0
# 32              Attacker     88.0            68.0
# 36              Attacker     88.0            73.0
# 38              Attacker     88.0            73.0
# 43              Attacker     87.0            61.0
# 47              Attacker     87.0            75.0
# 48              Attacker     87.0            73.0
# ...

# %%
plt.scatter(gb_attacker["Overall"],gb_attacker["Height(Inches)"],edgecolors="black",facecolors="red")
plt.title("Attacker Height vs Attacker Overall Rating ")
plt.xlabel("Overall Rating")
plt.ylabel("Height(Inches)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()
plt.savefig("Attacker_Height_vs_Attacker_Overall_Rating.png")

# %%
gb_defender = height_position_df.groupby("Simplified Position")
gb_defender = gb_defender.get_group("Defenders")
gb_defender.head()
# Out:
#    Simplified Position  Overall  Height(Inches)
# 8            Defenders     91.0            72.0
# 12           Defenders     90.0            74.0
# 24           Defenders     89.0            74.0
# 34           Defenders     88.0            75.0
# 35           Defenders     88.0            69.0

# %%
plt.scatter(gb_defender["Overall"],gb_defender["Height(Inches)"],edgecolors="black",facecolors="green")
plt.title("Defender Height vs Defender Overall Rating ")
plt.xlabel("Overall Rating")
plt.ylabel("Height(Inches)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()
plt.savefig("Defender_Height_vs_Defender_Overall_Rating.png")

# %%
gb_keeper = height_position_df.groupby("Simplified Position")
gb_keeper = gb_keeper.get_group("Goalkeeper")
gb_keeper.head()
# Out:
#    Simplified Position  Overall  Height(Inches)
# 3           Goalkeeper     91.0            76.0
# 9           Goalkeeper     90.0            74.0
# 18          Goalkeeper     89.0            74.0
# 19          Goalkeeper     89.0            78.0
# 22          Goalkeeper     89.0            76.0

# %%
plt.scatter(gb_keeper["Overall"],gb_keeper["Height(Inches)"],edgecolors="black",facecolors="blue")
plt.title("Goalkeeper Height vs Goalkeeper Overall Rating ")
plt.xlabel("Overall Rating")
plt.ylabel("Height(Inches)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()
plt.savefig("Goalkeeper_Height_vs_Goalkeeper_Overall_Rating.png")

# %%
gb_midfielder = height_position_df.groupby("Simplified Position")
gb_midfielder = gb_midfielder.get_group("Midfielder")
gb_midfielder.head()
# Out:
#    Simplified Position  Overall  Height(Inches)
# 4           Midfielder     91.0            61.0
# 6           Midfielder     91.0            68.0
# 11          Midfielder     90.0            72.0
# 13          Midfielder     90.0            68.0
# 14          Midfielder     89.0            66.0

# %%
plt.scatter(gb_midfielder["Overall"],gb_midfielder["Height(Inches)"],edgecolors="black",facecolors="orange")
plt.title("Midfielder Height vs Midfielder Overall Rating ")
plt.xlabel("Overall Rating")
plt.ylabel("Height(Inches)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()
plt.savefig("Midfielder_Height_vs_Midfielder_Overall_Rating.png")

# %%
gb_attacker_mean = gb_attacker.mean()
gb_attacker_mean
# Out:
# Overall           79.897436
# Height(Inches)    68.380952
# dtype: float64

# %%
gb_defender_mean = gb_defender.mean()
gb_defender_mean
# Out:
# Overall           79.506812
# Height(Inches)    70.517711
# dtype: float64

# %%
gb_keeper_mean = gb_keeper.mean()
gb_keeper_mean
# Out:
# Overall           80.246269
# Height(Inches)    74.492537
# dtype: float64

# %%
gb_midfielder_mean = gb_midfielder.mean()
gb_midfielder_mean
# Out:
# Overall           79.478976
# Height(Inches)    67.630713
# dtype: float64

# %%
overall_mean = [79.8, 79.5, 80.2, 79.4]
height_mean = [68.3, 70.5, 74.4, 67.6]
x_index = ['Attacker', 'Defender', 'Keeper',
    'Midfielder']

bar_mean_df = pd.DataFrame({'Rating': overall_mean,
    'Height': height_mean}, index=index)

bar_mean_df.plot.bar(rot=0)
plt.xlabel("Player Positions")
plt.ylabel("Rating and Height")
plt.title("Mean Rating vs Mean Height Per Position")
plt.savefig("Mean Rating vs Mean Height Per Position")
